# %%
from IPython.display import clear_output
import random
import time

print(" 7 | 8 | 9   0 | O | ° \
    \n---+---+--- ---+---+---\
    \n 4 | 5 | 6   O | o | ° \
    \n---+---+--- ---+---+---\
    \n 1 | 2 | 3   X | x | * \
    \n \
    \n S is small, M is medium, L is large")

def again():
    print("Play again? (Enter)")
    inp = input("Play again? (Enter)")
    if inp == "":
        game()

def output(x):
    clear_output(wait=True)
    print(" {k[6]} | {k[7]} | {k[8]}   {v[6]} | {v[7]} | {v[8]} \
        \n---+---+--- ---+---+---\
        \n {k[3]} | {k[4]} | {k[5]}   {v[3]} | {v[4]} | {v[5]} \
        \n---+---+--- ---+---+---\
        \n {k[0]} | {k[1]} | {k[2]}   {v[0]} | {v[1]} | {v[2]} \
        \n \
        \n S is small, M is medium, L is large".format(
        k=[i if x[i] == " " else " " for i in x], v=[*x.values()]), flush=True)
    time.sleep(0.01)

def game():
    x = {1: " ", 2: " ", 3: " ",  4: " ", 5: " ", 6: " ", 7: " ", 8: " ", 9: " "}

    x[random.choice([1, 3, 7, 9])] = "X"

    output(x)

    for i in range(4):
        while True:
            try:
                onum = int(input("Where do you want to go? (1 - 9)"))
                if x[onum] == " ":
                    x[onum] = "O"
                    break
                else:
                    print("Try Again")
                    continue
            except:
                print("Try Again")
                continue

        output(x)

        if any({x[1] == "O" and x[2] == "O" and x[3] == "O",
                x[4] == "O" and x[5] == "O" and x[6] == "O",
                x[7] == "O" and x[8] == "O" and x[9] == "O",
                x[1] == "O" and x[4] == "O" and x[7] == "O",
                x[2] == "O" and x[5] == "O" and x[8] == "O",
                x[3] == "O" and x[6] == "O" and x[9] == "O",
                x[1] == "O" and x[5] == "O" and x[9] == "O",
                x[3] == "O" and x[5] == "O" and x[7] == "O"}):
            print("You win")
            again()
            break

        if i == 0:
            if x[1] == "X":
                if x[9] == " ":
                    x[9] = "X"
                elif x[9] == "O":
                    x[random.choice([3, 7])] = "X"
            elif x[9] == "X":
                if x[1] == " ":
                    x[1] = "X"
                elif x[1] == "O":
                    x[random.choice([3, 7])] = "X"
            elif x[3] == "X":
                if x[7] == " ":
                    x[7] = "X"
                elif x[7] == "O":
                    x[random.choice([1, 9])] = "X"
            elif x[7] == "X":
                if x[3] == " ":
                    x[3] = "X"
                elif x[3] == "O":
                    x[random.choice([1, 9])] = "X"

        if i == 1:
            if x[1] == "X" and x[9] == "X":
                if x[5] == " ":
                    x[5] = "X"  # end
                elif x[4] == "O":
                    x[6] = "X"
                elif x[7] == "O":
                    x[3] = "X"
                elif x[8] == "O":
                    x[2] = "X"
                elif x[6] == "O":
                    x[4] = "X"
                elif x[3] == "O":
                    x[7] = "X"
                elif x[2] == "O":
                    x[8] = "X"
            elif x[3] == "X" and x[7] == "X":
                if x[5] == " ":
                    x[5] = "X"  # end
                elif x[4] == "O":
                    x[6] = "X"
                elif x[1] == "O":
                    x[9] = "X"
                elif x[2] == "O":
                    x[8] = "X"
                elif x[6] == "O":
                    x[4] = "X"
                elif x[9] == "O":
                    x[1] = "X"
                elif x[8] == "O":
                    x[2] = "X"
            elif x[1] == "X" and x[3] == "X":
                if x[2] == " ":
                    x[2] = "X"  # end
                elif x[7] == " ":
                    x[7] = "X"
                elif x[9] == " ":
                    x[9] = "X"
            elif x[3] == "X" and x[9] == "X":
                if x[6] == " ":
                    x[6] = "X"  # end
                elif x[1] == " ":
                    x[1] = "X"
                elif x[7] == " ":
                    x[7] = "X"
            elif x[9] == "X" and x[7] == "X":
                if x[8] == " ":
                    x[8] = "X"  # end
                elif x[1] == " ":
                    x[1] = "X"
                elif x[3] == " ":
                    x[3] = "X"
            elif x[7] == "X" and x[1] == "X":
                if x[4] == " ":
                    x[4] = "X"  # end
                elif x[9] == " ":
                    x[9] = "X"
                elif x[3] == " ":
                    x[3] = "X"

        if i == 2:
            if x[1] == "X" and x[9] == "X" and x[2] == "X":
                if x[3] == " ":
                    x[3] = "X"  # end
                elif x[7] == " ":
                    x[7] = "X"
            elif x[1] == "X" and x[9] == "X" and x[4] == "X":
                if x[7] == " ":
                    x[7] = "X"  # end
                elif x[3] == " ":
                    x[3] = "X"
            elif x[1] == "X" and x[9] == "X" and x[6] == "X":
                if x[3] == " ":
                    x[3] = "X"  # end
                elif x[7] == " ":
                    x[7] = "X"
            elif x[1] == "X" and x[9] == "X" and x[8] == "X":
                if x[7] == " ":
                    x[7] = "X"  # end
                elif x[3] == " ":
                    x[3] = "X"

            elif x[3] == "X" and x[7] == "X" and x[2] == "X":
                if x[1] == " ":
                    x[1] = "X"  # end
                elif x[9] == " ":
                    x[9] = "X"
            elif x[3] == "X" and x[7] == "X" and x[4] == "X":
                if x[1] == " ":
                    x[1] = "X"  # end
                elif x[9] == " ":
                    x[9] = "X"
            elif x[3] == "X" and x[7] == "X" and x[6] == "X":
                if x[9] == " ":
                    x[9] = "X"  # end
                elif x[1] == " ":
                    x[1] = "X"
            elif x[3] == "X" and x[7] == "X" and x[8] == "X":
                if x[9] == " ":
                    x[9] = "X"  # end
                elif x[1] == " ":
                    x[1] = "X"

            elif x[1] == "X" and x[3] == "X" and x[9] == "X":  # end
                if x[5] == " ":
                    x[5] = "X"
                elif x[2] == " ":
                    x[2] = "X"
                elif x[6] == " ":
                    x[6] = "X"
            elif x[3] == "X" and x[9] == "X" and x[7] == "X":  # end
                if x[5] == " ":
                    x[5] = "X"
                elif x[6] == " ":
                    x[6] = "X"
                elif x[8] == " ":
                    x[8] = "X"
            elif x[9] == "X" and x[7] == "X" and x[1] == "X":  # end
                if x[5] == " ":
                    x[5] = "X"
                elif x[4] == " ":
                    x[4] = "X"
                elif x[8] == " ":
                    x[8] = "X"
            elif x[7] == "X" and x[1] == "X" and x[3] == "X":  # end
                if x[5] == " ":
                    x[5] = "X"
                elif x[2] == " ":
                    x[2] = "X"
                elif x[4] == " ":
                    x[4] = "X"

        if i == 3:
            for k in x.keys():
                print(x[k])
                if x[k] == " ":
                    x[k] = "X"

        output(x)

        if any({x[1] == "X" and x[2] == "X" and x[3] == "X",
                x[4] == "X" and x[5] == "X" and x[6] == "X",
                x[7] == "X" and x[8] == "X" and x[9] == "X",
                x[1] == "X" and x[4] == "X" and x[7] == "X",
                x[2] == "X" and x[5] == "X" and x[8] == "X",
                x[3] == "X" and x[6] == "X" and x[9] == "X",
                x[1] == "X" and x[5] == "X" and x[9] == "X",
                x[3] == "X" and x[5] == "X" and x[7] == "X"}):
            print("Computer wins")
            again()
            break

        elif " " not in list(x.values()):
            print("Draw")
            again()

game()
# Out:
#  7 | 8 | 9     |   |
# ---+---+--- ---+---+---
#  4 | 5 | 6     |   |
# ---+---+--- ---+---+---
#  1 | 2 |       |   | X
#
#  S is small, M is medium, L is large
# Try Again
# Try Again
# Try Again
# Try Again
# Try Again
# Try Again
# Try Again
